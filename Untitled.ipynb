# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('archive(1)/loan_sanction_train.csv')
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Length: 614, dtype: bool

# %%
df=pd.DataFrame({'temp':[20,22,18,7,7,11,17,15],'alt':[10,15,60,100,120,90,78,12]})
plt.scatter(df['alt'],df['temp'])
#plt.plot(df['alt'],-6/40*df['alt']+23,c='r')
plt.plot(X,a*X+b)
print(df.corr())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3005/829897542.py in <module>
#       2 plt.scatter(df['alt'],df['temp'])
#       3 #plt.plot(df['alt'],-6/40*df['alt']+23,c='r')
# ----> 4 plt.plot(X,a*X+b)
#       5 print(df.corr())
#       6 plt.show()
#
# NameError: name 'X' is not defined

# %%
Y=np.array([20,22,18,7,7,11,17,15])
X=np.array([10,15,60,100,120,90,78,12])
jh=[]
a=-1
b=0.2
alpha=0.01
for i in range(100):
    Yh=a*X+b
    E=Y-Yh
    J=E.dot(E)/X.shape[0]
    dja=X.dot(E)/X.shape[0]
    djb=np.sum(E)/X.shape[0]
    a=a-alpha*dja
    b=b-alpha*djb
    jh.append(J)
print(a)
print(b)
print(E.ndim)

# %%
import numpy as np
X=np.array([10,15,60,100,120,90,78,12])

pr

# %%
plt.plot(a*X+b)

# %%
import pandas as pd
df=pd.read_csv('archive(2)/data.csv')
df

# %%
import numpy as np
import numpy.linalg as nlg
import pandas as pd
import matplotlib.pyplot as plt
X=np.linspace(0.001,5,6)
Y=np.array([4800,3400,2420,2000,1760,1723])
np.corrco
# Out:
# [1.0000e-03 1.0008e+00 2.0006e+00 3.0004e+00 4.0002e+00 5.0000e+00]

# %%
data=pd.DataFrame([X,Y,np.log(X)]).T

y=np.log(Y)
x=np.stack((np.ones(len(X)),X)).T
w=nlg.inv(x.T.dot(x)).dot(x.T).dot(y)
print(w)
plt.scatter(X,Y)
plt.plot(X,np.exp(w[0])*np.exp(w[1]*X))
# Out:
# [ 8.34170305 -0.20829166]

# %%
data=pd.DataFrame([X,Y,np.log(X),np.log(Y)]).T
#data0=pd.DataFrame([np.log(X),np.log(Y)]).T
print(data.corr())
#print(data0.corr())
# Out:
#           0         1         2         3
# 0  1.000000 -0.916509  0.772830 -0.954741
# 1 -0.916509  1.000000 -0.932567  0.990880
# 2  0.772830 -0.932567  1.000000 -0.881640
# 3 -0.954741  0.990880 -0.881640  1.000000

# %%
#hyp1
X0=np.stack((np.ones(len(X)),X)).T
W=nlg.inv(X0.T.dot(X0)).dot(X0.T).dot(Y)

#hyp2
X1=np.stack((np.ones(len(X)),X)).T
W1=nlg.inv(X1.T.dot(X1)).dot(X1.T).dot(np.log(Y))

#hyp3
X2=np.stack((np.ones(len(X)),np.log(X))).T
W2=nlg.inv(X2.T.dot(X2)).dot(X2.T).dot(np.log(Y))

#hyp4
X3=np.stack((np.ones(len(X)),np.log(X))).T
W3=nlg.inv(X3.T.dot(X3)).dot(X3.T).dot(Y)
xx=np.linspace(0.001,6,100)
plt.scatter(X,Y)
plt.plot(xx,np.exp(W1[0])*np.exp(W1[1]*xx),c='r')
plt.plot(X,W.dot(X0.T))
plt.plot(X,W2.dot(X2.T))
plt.plot(X,W3.dot(X3.T))
# Out:
# [[1.0000e+00 1.0000e-03]
#  [1.0000e+00 1.0008e+00]
#  [1.0000e+00 2.0006e+00]
#  [1.0000e+00 3.0004e+00]
#  [1.0000e+00 4.0002e+00]
#  [1.0000e+00 5.0000e+00]]

# %%
#x=1
x
# Out:
# 1

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.constituteproject.org/constitution/Morocco_2011?lang=ar"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find_all('section',class_="article-list level0 article-title")
#job_elements = results.find_all("h3", class_="depth-0")
#job_elements=[{'tag':[],'fosol':{}}]

job_elements=[]
for res in results:
    fosol=res.find_all('section',class_="article-list level1 article-title")
    try:
        dic={'tag':[res.find("h3", class_="depth-0").text]}
        for fasl in fosol:
            fasl.find_all('section',class_="article-list level2 article-body")
            dic[fasl.find('h3',class_="depth-1").text]=' '.join([fa.text for fa in fasl if fa.text!='\n'])
            #print(dic)
        job_elements += [dic]
    
    except AttributeError:
        pass
        
#print(job_elements)
for job in job_elements:
    print(job)
    pass

# %%
from bs4 import BeautifulSoup

URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
dic={'tag':'dds'}
dic['tag1']='fsd'
dic
