# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('archive(1)/loan_sanction_train.csv')
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Length: 614, dtype: bool

# %%
df=pd.DataFrame({'temp':[20,22,18,7,7,11,17,15],'alt':[10,15,60,100,120,90,78,12]})
plt.scatter(df['alt'],df['temp'])
#plt.plot(df['alt'],-6/40*df['alt']+23,c='r')
plt.plot(X,a*X+b)
print(df.corr())
plt.show()
# Out:
#          temp      alt
# temp  1.00000 -0.82919
# alt  -0.82919  1.00000

# %%
Y=np.array([20,22,18,7,7,11,17,15])
X=np.array([10,15,60,100,120,90,78,12])
jh=[]
a=-1
b=0.2
alpha=0.01
for i in range(100):
    Yh=a*X+b
    E=Y-Yh
    J=E.dot(E)/X.shape[0]
    dja=X.dot(E)/X.shape[0]
    djb=np.sum(E)/X.shape[0]
    a=a-alpha*dja
    b=b-alpha*djb
    jh.append(J)
print(a)
print(b)
print(E.ndim)
# Out:
# -3.56085566002409e+173
# -4.049224231120726e+171
# 1

# %%
import numpy as np
X=np.array([10,15,60,100,120,90,78,12])

pr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11885/2283445141.py in <module>
#       2 X=np.array([10,15,60,100,120,90,78,12])
#       3
# ----> 4 print(X.shape())
#
# TypeError: 'tuple' object is not callable

# %%
plt.plot(a*X+b)

# %%
import pandas as pd
df=pd.read_csv('archive(2)/data.csv')
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
import numpy as np
import numpy.linalg as nlg
import pandas as pd
import matplotlib.pyplot as plt
X=np.linspace(0.001,5,6)
Y=np.array([4800,3400,2420,2000,1760,1723])
np.corrcoef(X,Y)
# Out:
# array([[ 1.        , -0.91650866],
#        [-0.91650866,  1.        ]])

# %%
data=pd.DataFrame([X,Y,np.log(X)]).T

y=np.log(Y)
x=np.stack((np.ones(len(X)),X)).T
w=nlg.inv(x.T.dot(x)).dot(x.T).dot(y)
print(w)
plt.scatter(X,Y)
plt.plot(X,np.exp(w[0])*np.exp(w[1]*X))
# Out:
# [ 8.34170305 -0.20829166]

# %%
data=pd.DataFrame([X,Y,np.log(Y)]).T
data0=pd.DataFrame([np.log(X),np.log(Y)]).T
print(data.corr())
print(data0.corr())
# Out:
#           0         1         2
# 0  1.000000 -0.916509 -0.954741
# 1 -0.916509  1.000000  0.990880
# 2 -0.954741  0.990880  1.000000
#          0        1
# 0  1.00000 -0.88164
# 1 -0.88164  1.00000

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.constituteproject.org/constitution/Morocco_2011?lang=ar"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find_all('section',class_="article-list level0 article-title")
#job_elements = results.find_all("h3", class_="depth-0")
#job_elements=[{'tag':[],'fosol':{}}]

job_elements=[]
for res in results:
    try:
        job_elements += [{'tag':[res.find("h3", class_="depth-0").text],'fosol':{''}}]
    except:
        pass
print(job_elements)
for job in job_elements:
    #print(job+"\n")
    pass
# Out:
# [{'tag': ['الباب الأول. أحكام عامة']}, {'tag': ['الباب الثاني. الحريات والحقوق الأساسية']}, {'tag': ['الباب الثالث. الملكية']}, {'tag': ['الباب الرابع. السلطة التشريعية']}, {'tag': ['الباب الخامس . السلطة التنفيذية']}, {'tag': ['الباب السادس . العلاقات بين السلط']}, {'tag': ['الباب السابع . السلطة القضائية']}, {'tag': ['الباب الثامن . المحكمة الدستورية']}, {'tag': ['الباب التاسع . الجهات والجماعات الترابية الأخرى']}, {'tag': ['الباب العاشر . المجلس الأعلى للحسابات']}, {'tag': ['الباب الحادي عشر . المجلس الاقتصادي والاجتماعي والبيئي']}, {'tag': ['الباب الثاني عشر . الحكامة الجيدة']}, {'tag': ['الباب الثالث عشر . مراجعة الدستور']}, {'tag': ['الباب الرابع عشر . أحكام انتقالية وختامية']}]

# %%
from bs4 import BeautifulSoup

URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
